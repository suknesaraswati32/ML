# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                                           title  \
# 0     1560520           Batman: Knightfall Part 1: Knightfall
# 1      980431                 Avatar Aang: The Last Airbender
# 2     1007757                                         Swapped
# 3     1632181                             Accidental Partners
# 4     1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# ...       ...                                             ...
# 8555   548473                              Color Out of Space
# 8556   331313                     Keeping Up with the Joneses
# 8557    36670                           Never Say Never Again
# 8558    15092                             Crank: High Voltage
# 8559    11428                                    Sleepwalkers
#
#                                                overview release_date  \
# 0     Arkham Asylum has been destroyed, and all its ...   2026-06-23
# 1     Avatar Aang, the world's last Airbender, learn...   2026-07-24
# 2     A small woodland creature and a majestic bird,...   2026-05-01
# 3     Two women discover they were both scammed by t...   2026-03-12
# 4     The Demon Slayer Corps are drawn into the Infi...   2025-07-18
# ...                                                 ...          ...
# 8555  The Gardner family moves to a remote farmstead...   2020-01-24
# 8556  An ordinary suburban couple finds it’s not eas...   2016-10-20
# 8557  James Bond returns as the secret agent 007 to ...   1983-10-07
# 8558  Chelios faces a Chinese mobster who has stolen...   2009-04-16
# 8559  Charles Brady and his mother, Mary, are the la...   1992-04-10
#
#       popularity  vote_average  vote_count
# 0        70.0571         9.200         379
# 1        75.6223         9.151        1186
# 2        43.0170         8.869        2202
# 3        15.6418         8.834         386
# 4        57.1426         8.800        2173
# ...          ...           ...         ...
# 8555      8.5347         6.089        1780
# 8556      7.8777         6.089        2190
# 8557     10.3504         6.087        1688
# 8558     12.0729         6.089        3266
# 8559      5.1765         6.089         648
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
