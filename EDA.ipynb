# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
df['Sex'].value_counts().plot(kind='bar')
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
# df['Pclass'].value_counts().plot(kind='pie')
# df['Sex'].value_counts().plot(kind='pie')
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#numerical data
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=50)
# Out:
# (array([ 8.,  3.,  0.,  4.,  1.,  4.,  2.,  3.,  3.,  4.,  2., 20.,  7.,
#         25., 17., 28., 11., 25.,  8., 25., 12.,  8.,  7., 10.,  6.,  7.,
#         11.,  5.,  5.,  9.,  8.,  5.,  8.,  1.,  3.,  2.,  6.,  3.,  2.,
#          4.,  3.,  2.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.17  ,  1.6866,  3.2032,  4.7198,  6.2364,  7.753 ,  9.2696,
#         10.7862, 12.3028, 13.8194, 15.336 , 16.8526, 18.3692, 19.8858,
#         21.4024, 22.919 , 24.4356, 25.9522, 27.4688, 28.9854, 30.502 ,
#         32.0186, 33.5352, 35.0518, 36.5684, 38.085 , 39.6016, 41.1182,
#         42.6348, 44.1514, 45.668 , 47.1846, 48.7012, 50.2178, 51.7344,
#         53.251 , 54.7676, 56.2842, 57.8008, 59.3174, 60.834 , 62.3506,
#         63.8672, 65.3838, 66.9004, 68.417 , 69.9336, 71.4502, 72.9668,
#         74.4834, 76.    ]),
#  <BarContainer object of 50 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11300\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#boxplot
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].skew()
# Out:
# np.float64(0.4573612871503845)

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('tips')
titanic=pd.read_csv('tested.csv')
flights=sns.load_dataset('flights')
iris=sns.load_dataset('iris')
tips=sns.load_dataset('tips')

# %%
#numerical numerical-Scatterplot
tips.head()
sns.scatterplot(data=tips, x='total_bill', y='tip',hue=df['sex'],style=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#bar plot (numerical categorical)
titanic.head()
sns.barplot(data=titanic, x='Pclass', y='Fare',hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#Boxplot(Numerical-categorical)
sns.boxplot(data=titanic,x='Sex',y='Age',hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#distplot (numerical-categorical)
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11300\57571343.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11300\57571343.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Heatmap-categorical-categorical
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#clustermap(categorical-categorical)
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %%
#pairplot
#plot scatterplot btn all the numerical col in data
sns.pairplot(iris,hue='species')

# %%
# #Lineplot(numerical-numerical)
# flights.groupby('year').sum().reset_index()
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11300\3757374502.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
import pandas as pd
df=pd.read_csv('tested.csv')

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Using cached phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (4.6.0)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\admin\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\admin\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\admin\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\admin\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: imagehash, wordcloud, visions, phik, ydata-profiling
#
#    -------- ------------------------------- 1/5 [wordcloud]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ---------------- ----------------------- 2/5 [visions]
#    ------------------------ --------------- 3/5 [phik]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    -------------------------------- ------- 4/5 [ydata-profiling]
#    ---------------------------------------- 5/5 [ydata-profiling]
#
# Successfully installed imagehash-4.3.2 phik-0.12.5 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ADMIN\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ADMIN\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ADMIN\anaconda3\Lib\site-packages)
